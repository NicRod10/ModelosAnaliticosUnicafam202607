# %% [markdown]
# <a href="https://colab.research.google.com/github/NicRod10/ModelosAnaliticosUnicafam202607/blob/main/Actividad_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # OPERADORES ARITMETICOS

# %%
#PRIMER EJERCICIO
a=10
b=3

# %%
#SEGUNDO EJERCICIO
print(a+b)
# Out:
# 13

# %%
#TERCER EJERCICIO
print(a-b)
# Out:
# 7

# %%
#CUARTO EJERCICIO
print(a*b)
# Out:
# 30

# %%
#QUINTO EJERCICIO
print(a/b)
# Out:
# 3.3333333333333335

# %%
#SEXTO EJERCICIO
print(a%b)
# Out:
# 1

# %%
#SEPTIMO EJERCICIO
print(a**b)
# Out:
# 1000

# %%
#OCTAVO EJERCICIO
print(a//b)
# Out:
# 3
